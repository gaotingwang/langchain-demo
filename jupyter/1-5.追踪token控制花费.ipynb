# %%
# llm的token追踪
from langchain_openai import OpenAI
from langchain.callbacks import get_openai_callback
import os

os.environ["OPENAI_API_KEY"] = "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"
os.environ["OPENAI_PROXY"] = "https://api.openai.com/v1"

api_base = os.getenv("OPENAI_PROXY")
api_key = os.getenv("OPENAI_API_KEY")

llm = OpenAI(
    model= "gpt-3.5-turbo-instruct",
    temperature=0,
    openai_api_key = api_key,
    openai_api_base = api_base,
    max_tokens=512,
)

with get_openai_callback() as cb:
    result = llm.invoke("给我讲一个笑话")
    print(result)
    print(cb)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[3], line 21
#      12 llm = OpenAI(
#      13     model= "gpt-3.5-turbo-instruct",
#      14     temperature=0,
#    (...)
#      17     max_tokens=512,
#      18 )
#      20 with get_openai_callback() as cb:
# ---> 21     result = llm.invoke("给我讲一个笑话")
#      22     print(result)
#      23     print(cb)
#
# File D:\py\ai\langchain-env\Lib\site-packages\langchain_core\language_models\llms.py:390, in BaseLLM.invoke(self, input, config, stop, **kwargs)
#     380 def invoke(
#     381     self,
#     382     input: LanguageModelInput,
#    (...)
#     386     **kwargs: Any,
#     387 ) -> str:
#     388     config = ensure_config(config)
#     389     return (
# --> 390         self.generate_prompt(
#     391             [self._convert_input(input)],
#     392             stop=stop,
# ...

# %%
# chatmodels的流式调用方法
from langchain.chat_models import ChatOpenAI
from langchain.callbacks import get_openai_callback
import os
os.environ["OPENAI_API_KEY"] = "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"
os.environ["OPENAI_PROXY"] = "https://ai-yyds.com/v1"

api_base = os.getenv("OPENAI_PROXY")
api_key = os.getenv("OPENAI_API_KEY")

llm = ChatOpenAI(
    model="gpt-4",
    temperature=0,
    openai_api_key = api_key,
    openai_api_base = api_base,
    max_tokens=512,
)

with get_openai_callback() as cb:
    result = llm.invoke("给我讲一个笑话")
    print(result)
    print(cb)
